# %%
def read_file(file):
    set_f = set()
    f = open(file, 'r')
    while True:
        line = f.readline()
        if not line: break
        set_f.add(line[:-1])
    f.close()
    return set_f

# %%
def read_pfile(file):
    set_f = {}
    f = open(file, 'r')
    while True:
        line = f.readline()
        if not line: break
        linesp = (line.split())
        #print(linesp)
        key = str(linesp[0])
        
        set_f[key] = int(linesp[1])
        #print(key)
        #print(linesp[1])
        #set_f.add(line[:-1])
        
    
    
    #print(set_f)
    f.close()
    return set_f

# %%
nw = "negative-words.txt"
pw = "positive-words.txt"

nw_s = read_file(nw)
pw_s = read_file(pw)

score = 0

# %%
set_f = {"nonono":1}
a = "g"
set_f[a] = 2
set_f
# Out:
# {'g': 2, 'nonono': 1}

# %%
test = read_pfile("test.txt")
test
# Out:
# {'대통령': 190,
#  '것': 131,
#  '전': 124,
#  '안': 117,
#  '문재인': 103,
#  '안철수': 93,
#  '의원': 86,
#  '고': 83,
#  '후보': 80,
#  '장관': 77,
#  '일': 74,
#  '민주당': 74,
#  '기사': 73,
#  '문': 70,
#  '정부': 69,
#  '후보자': 68,
#  '년': 68,
#  '전술핵': 62,
#  '추천': 60,
#  '정치': 57,
#  '김': 57,
#  '대표': 56,
#  '등': 53,
#  '관련': 49,
#  '창': 49,
#  '수': 48,
#  '만': 48,
#  '인사': 45,
#  '카드': 44,
#  '미국': 41,
#  '기자': 40,
#  '배치': 39,
#  '국민': 39,
#  '개혁': 39,
#  '대선': 39,
#  '검찰': 39,
#  '위원장': 38,
#  '사설': 38,
#  '그': 38,
#  '이': 36,
#  '정책': 36,
#  '재': 36,
#  '우리': 35,
#  '청와대': 34,
#  '며': 34,
#  '론': 34,
#  '압박': 34,
#  '김순덕': 34,
#  '대북': 33,
#  '운동': 33,
#  '개월': 33,
#  '뉴스': 32,
#  '칼럼': 32,
#  '순': 32,
#  '비수': 32,
#  '제재': 31,
#  '원장': 31,
#  '반도': 31,
#  '숙명': 31,
#  '따윈': 31,
#  '무기': 31,
#  '한반도': 31,
#  '박지원': 31,
#  '내각': 31,
#  '베스트': 30,
#  '전자': 30,
#  '장비': 30,
#  '먹통': 30,
#  '공': 30,
#  '박정희': 30,
#  '기념우표': 30,
#  '발행': 30,
#  '촉구': 30,
#  '서명': 30,
#  '조': 30,
#  '수석': 30,
#  '새': 29,
#  '건': 28,
#  '안보': 27,
#  '때': 27,
#  '원': 27,
#  '단일': 27,
#  '출마': 27,
#  '외교': 26,
#  '날': 26,
#  '출신': 26,
#  '정당': 26,
#  '신당': 26,
#  '를': 25,
#  '더': 25,
#  '문제': 24,
#  '뒤': 24,
#  '한국': 23,
#  '보기': 23,
#  '민주': 23,
#  '지방선거': 23,
#  '회장': 22,
#  '임명': 22,
#  '연대': 22,
#  '서울': 21,
#  '명': 21,
#  '공약': 21,
#  '혁신': 21,
#  '여사': 20,
#  '노무현': 20,
#  '월': 20,
#  '가능성': 20,
#  '국회': 20,
#  '소득': 19,
#  '차관': 19,
#  '교육': 19,
#  '새정치': 19,
#  '선거': 19,
#  '국세청': 19,
#  '특보': 18,
#  '최고': 18,
#  '지역': 18,
#  '대한': 18,
#  '씨': 18,
#  '진보': 18,
#  '총장': 18,
#  '교육감': 18,
#  '야권': 18,
#  '교수': 17,
#  '말': 17,
#  '라며': 17,
#  '당선': 17,
#  '중심': 16,
#  '사실': 16,
#  '통해': 16,
#  '로': 16,
#  '점': 16,
#  '사회': 16,
#  '대해': 15,
#  '또': 15,
#  '의사': 15,
#  '의': 15,
#  '세율': 15,
#  '때문': 15,
#  '공동': 15,
#  '문화': 15,
#  '세력': 15,
#  '후': 14,
#  '사드': 14,
#  '실장': 14,
#  '이번': 14,
#  '경제': 14,
#  '위해': 14,
#  '선': 14,
#  '인상': 14,
#  '박근혜': 14,
#  '반대': 14,
#  '자신': 14,
#  '검찰총장': 14,
#  '국정': 14,
#  '국방': 14,
#  '당': 14,
#  '관': 13,
#  '사람': 13,
#  '관계자': 13,
#  '사의': 13,
#  '위원': 13,
#  '의료': 13,
#  '게': 13,
#  '당시': 13,
#  '지명': 13,
#  '서울대': 13,
#  '조사': 13,
#  '통합': 13,
#  '우려': 12,
#  '데': 12,
#  '상황': 12,
#  '책임': 12,
#  '제': 12,
#  '주의': 12,
#  '손': 12,
#  '첫': 12,
#  '비서': 12,
#  '법무부': 12,
#  '여성': 12,
#  '정치인': 12,
#  '양': 12,
#  '노환규': 12,
#  '차장': 11,
#  '발언': 11,
#  '중': 11,
#  '층': 11,
#  '임대주택': 11,
#  '법인세': 11,
#  '기업': 11,
#  '료': 11,
#  '도입': 11,
#  '결정': 11,
#  '수도': 11,
#  '위원회': 11,
#  '인선': 11,
#  '기': 11,
#  '현역': 11,
#  '새누리당': 11,
#  '라인': 10,
#  '회의': 10,
#  '분석': 10,
#  '에서': 10,
#  '전문가': 10,
#  '사업': 10,
#  '센터': 10,
#  '연': 10,
#  '채': 10,
#  '금리': 10,
#  '내': 10,
#  '대기업': 10,
#  '법무': 10,
#  '박': 10,
#  '부산': 10,
#  '정치권': 10,
#  '총선': 10,
#  '블랙리스트': 10,
#  '및': 9,
#  '정상회담': 9,
#  '구조': 9,
#  '다른': 9,
#  '홍': 9,
#  '앞': 9,
#  '의지': 9,
#  '방향': 9,
#  '도시재생': 9,
#  '우선': 9,
#  '억': 9,
#  '지원': 9,
#  '전국': 9,
#  '총량': 9,
#  '관리': 9,
#  '경우': 9,
#  '방안': 9,
#  '라면': 9,
#  '이후': 9,
#  '조직': 9,
#  '사퇴': 9,
#  '통화': 9,
#  '연합': 9,
#  '지지': 9,
#  '시절': 9,
#  '조국': 9,
#  '민정': 9,
#  '김부겸': 9,
#  '김영춘': 9,
#  '도종환': 9,
#  '국민의당': 9,
#  '시간': 8,
#  '한미': 8,
#  '크게': 8,
#  '자리': 8,
#  '내용': 8,
#  '생각': 8,
#  '시대': 8,
#  '시장': 8,
#  '기존': 8,
#  '주택': 8,
#  '곳': 8,
#  '구상': 8,
#  '공공': 8,
#  '교체': 8,
#  '공급': 8,
#  '뜻': 8,
#  '대출': 8,
#  '추진': 8,
#  '연구': 8,
#  '부담': 8,
#  '법': 8,
#  '분': 8,
#  '세금': 8,
#  '현실': 8,
#  '얘기': 8,
#  '배': 8,
#  '검': 8,
#  '발탁': 8,
#  '의혹': 8,
#  '고려대': 8,
#  '평가': 8,
#  '무': 8,
#  '캠프': 8,
#  '해군': 8,
#  '일이': 8,
#  '다시': 8,
#  '과정': 8,
#  '김상곤': 8,
#  '경기도': 8,
#  '관료': 8,
#  '처': 8,
#  '만큼': 8,
#  '서울시장': 8,
#  '듯': 8,
#  '벤처기업': 8,
#  '무소속': 8,
#  '선언': 8,
#  '강연': 8,
#  '합당': 8,
#  '두': 7,
#  '중앙': 7,
#  '정': 7,
#  '외부': 7,
#  '임기': 7,
#  '직접': 7,
#  '못': 7,
#  '줄': 7,
#  '준비': 7,
#  '부동산': 7,
#  '노': 7,
#  '재원': 7,
#  '계획': 7,
#  '집': 7,
#  '일자리': 7,
#  '비': 7,
#  '부채': 7,
#  '개편': 7,
#  '단계': 7,
#  '시': 7,
#  '대책': 7,
#  '여': 7,
#  '대법원': 7,
#  '거론': 7,
#  '제기': 7,
#  '업무': 7,
#  '지금': 7,
#  '국회의원': 7,
#  '국장': 7,
#  '측': 7,
#  '김현미': 7,
#  '로서': 7,
#  '감': 7,
#  '타이밍': 7,
#  '결과': 7,
#  '의협': 7,
#  '논설': 7,
#  '범': 7,
#  '당내': 7,
#  '취임': 6,
#  '초': 6,
#  '서관': 6,
#  '체계': 6,
#  '관계': 6,
#  '제대로': 6,
#  '표명': 6,
#  '간': 6,
#  '주거': 6,
#  '주거지': 6,
#  '수준': 6,
#  '산업': 6,
#  '개': 6,
#  '목표': 6,
#  '가계부채': 6,
#  '청년': 6,
#  '축소': 6,
#  '회': 6,
#  '금융': 6,
#  '빚': 6,
#  '책': 6,
#  '핵심': 6,
#  '한편': 6,
#  '지난': 6,
#  '볼': 6,
#  '건강': 6,
#  '증세': 6,
#  '소득세': 6,
#  '일단': 6,
#  '국가': 6,
#  '신': 6,
#  '오후': 6,
#  '약속': 6,
#  '내부': 6,
#  '걸': 6,
#  '정도': 6,
#  '발표': 6,
#  '교과서': 6,
#  '교육부': 6,
#  '국방부': 6,
#  '현': 6,
#  '반발': 6,
#  '청문회': 6,
#  '인물': 6,
#  '모두': 6,
#  '반': 6,
#  '운영': 6,
#  '탈세': 6,
#  '대통': 6,
#  '합': 6,
#  '위기': 6,
#  '지방': 6,
#  '질문': 6,
#  '김수남': 6,
#  '수사': 6,
#  '수사권': 6,
#  '경찰': 6,
#  '바람': 6,
#  '시인': 6,
#  '입각': 6,
#  '모든': 6,
#  '정권': 6,
#  '과연': 6,
#  '독자': 6,
#  '기득권': 6,
#  '분열': 6,
#  '동물원': 6,
#  '속': 5,
#  '처음': 5,
#  '부인': 5,
#  '논란': 5,
#  '공석': 5,
#  '강': 5,
#  '분야': 5,
#  '고위': 5,
#  '셈': 5,
#  '이상': 5,
#  '일정': 5,
#  '여당': 5,
#  '방법': 5,
#  '안정': 5,
#  '확보': 5,
#  '가장': 5,
#  '먼저': 5,
#  '지난해': 5,
#  '노후': 5,
#  '자산': 5,
#  '중소': 5,
#  '현재': 5,
#  '급': 5,
#  '기본': 5,
#  '폐지': 5,
#  '과제': 5,
#  '법정': 5,
#  '가계': 5,
#  '비율': 5,
#  '속도': 5,
#  '규제': 5,
#  '그동안': 5,
#  '확대': 5,
#  '조정': 5,
#  '추가': 5,
#  '검토': 5,
#  '언급': 5,
#  '대부분': 5,
#  '주장': 5,
#  '유권자': 5,
#  '뿐': 5,
#  '김정숙': 5,
#  '오전': 5,
#  '자택': 5,
#  '대검': 5,
#  '검사': 5,
#  '각각': 5,
#  '돈': 5,
#  '최': 5,
#  '성향': 5,
#  '판사': 5,
#  '최근': 5,
#  '위반': 5,
#  '이낙연': 5,
#  '총리': 5,
#  '대법관': 5,
#  '통한': 5,
#  '인준': 5,
#  '송영': 5,
#  '검증': 5,
#  '거듭': 5,
#  '방어': 5,
#  '부총리': 5,
#  '학교': 5,
#  '재직': 5,
#  '전격': 5,
#  '도전': 5,
#  '사과': 5,
#  '정국': 5,
#  '강화': 5,
#  '박원순': 5,
#  '풀이': 5,
#  '공수': 5,
#  '권한': 5,
#  '합의': 5,
#  '바로': 5,
#  '길': 5,
#  '비판': 5,
#  '일부': 5,
#  '친': 5,
#  '칼': 5,
#  '타파': 5,
#  '탈당': 5,
#  '호남': 5,
#  '벽': 5,
#  '선수': 5,
#  '예술': 5,
#  '안배': 5,
#  '체육': 5,
#  '쇄신': 5,
#  '모습': 5,
#  '민생': 5,
#  '격진': 5,
#  '투쟁': 5,
#  '거': 5,
#  '얼마나': 5,
#  '구현': 5,
#  '바보': 5,
#  '기초': 5,
#  '박성원': 5,
#  '난맥': 4,
#  '트럼프': 4,
#  '오른쪽': 4,
#  '특별': 4,
#  '사태': 4,
#  '석비': 4,
#  '명의': 4,
#  '연세대': 4,
#  '도움': 4,
#  '직후': 4,
#  '몇': 4,
#  '적': 4,
#  '개입': 4,
#  '반영': 4,
#  '차': 4,
#  '외교부': 4,
#  '더욱': 4,
#  '각종': 4,
#  '한상준': 4,
#  '믹스': 4,
#  '성': 4,
#  '전통': 4,
#  '규모': 4,
#  '예산': 4,
#  '총': 4,
#  '이전': 4,
#  '질': 4,
#  '시한': 4,
#  '폭탄': 4,
#  '김진표': 4,
#  '브레인': 4,
#  '성장': 4,
#  '효과': 4,
#  '대전': 4,
#  '보호': 4,
#  '긴장': 4,
#  '실현': 4,
#  '장기': 4,
#  '바': 4,
#  '경기': 4,
#  '감안': 4,
#  '서민': 4,
#  '입': 4,
#  '해결': 4,
#  '공식': 4,
#  '하나': 4,
#  '윤': 4,
#  '와': 4,
#  '주기': 4,
#  '보험': 4,
#  '전문': 4,
#  '고액': 4,
#  '부자': 4,
#  '갈등': 4,
#  '오히려': 4,
#  '경쟁': 4,
#  '홍은동': 4,
#  '호소': 4,
#  '하자': 4,
#  '사진': 4,
#  '경선': 4,
#  '북한': 4,
#  '미사일': 4,
#  '상임': 4,
#  '임종석': 4,
#  '임': 4,
#  '조현': 4,
#  '옥': 4,
#  '김경수': 4,
#  '대구': 4,
#  '진': 4,
#  '인천': 4,
#  '포석': 4,
#  '모임': 4,
#  '간사': 4,
#  '법원행정처': 4,
#  '반응': 4,
#  '기수': 4,
#  '간부': 4,
#  '수장': 4,
#  '치': 4,
#  '동아일보': 4,
#  '물': 4,
#  '탄핵': 4,
#  '준': 4,
#  '장': 4,
#  '편찬': 4,
#  '사학': 4,
#  '역사': 4,
#  '석': 4,
#  '운': 4,
#  '친문': 4,
#  '절대': 4,
#  '참여': 4,
#  '송': 4,
#  '하되': 4,
#  '주변': 4,
#  '군': 4,
#  '과': 4,
#  '본부장': 4,
#  '경북': 4,
#  '필요': 4,
#  '참모': 4,
#  '오랫동안': 4,
#  '무상급식': 4,
#  '총학생회': 4,
#  '경영학': 4,
#  '전교조': 4,
#  '공천': 4,
#  '지능': 4,
#  '보궐선거': 4,
#  '당권': 4,
#  '주자': 4,
#  '경력': 4,
#  '본부': 4,
#  '간섭': 4,
#  '이기': 4,
#  '행정자치부': 4,
#  '표정': 4,
#  '끝': 4,
#  '단체': 4,
#  '정무': 4,
#  '해양': 4,
#  '접시꽃': 4,
#  '당신': 4,
#  '돌파': 4,
#  '문체부': 4,
#  '도': 4,
#  '위': 4,
#  '기자회견': 4,
#  '권리': 4,
#  '물론': 4,
#  '알': 4,
#  '회동': 4,
#  '지지율': 4,
#  '반드시': 4,
#  '힘': 4,
#  '파업': 4,
#  '명분': 4,
#  '실제': 4,
#  '전의총': 4,
#  '공감': 4,
#  '통합신당': 4,
#  '국본': 4,
#  '꿈': 4,
#  '스포트라이트': 4,
#  '가치': 4,
#  '눈앞': 4,
#  '설': 4,
#  '측은': 4,
#  '방법론': 4,
#  '비상': 4,
#  '구도': 4,
#  '친구': 4,
#  '미래': 4,
#  '스스로': 4,
#  '논의': 4,
#  '뉴시스': 3,
#  '문정인': 3,
#  '공개': 3,
#  '신설': 3,
#  '국가안보실': 3,
#  '경험': 3,
#  '잡음': 3,
#  '지난달': 3,
#  '명예': 3,
#  '고고': 3,
#  '미사일방어': 3,
#  '본인': 3,
#  '이야기': 3,
#  '사전': 3,
#  '관측': 3,
#  '열흘': 3,
#  '통일부': 3,
#  '실무': 3,
#  '의견': 3,
#  '당초': 3,
#  '영향력': 3,
#  '전날': 3,
#  '무대': 3,
#  '의미': 3,
#  '성과': 3,
#  '목소리': 3,
#  '개발': 3,
#  '환경': 3,
#  '구체': 3,
#  '달성': 3,
#  '행보': 3,
#  '재개발': 3,
#  '차별': 3,
#  '국토교통부': 3,
#  '기준': 3,
#  '정비': 3,
#  '적지': 3,
#  '재정': 3,
#  '원대': 3,
#  '국토': 3,
#  '대상': 3,
#  '시행': 3,
#  '주민': 3,
#  '저울': 3,
#  '이용섭': 3,
#  '조윤제': 3,
#  '홍종학': 3,
#  '분수': 3,
#  '환': 3,
#  '협치': 3,
#  '시험대': 3,
#  '골목': 3,
#  '상권': 3,
#  '대형': 3,
#  '유통업체': 3,
#  '휴대전화': 3,
#  '혹시': 3,
#  '포스코': 3,
#  '대우조선': 3,
#  '회생': 3,
#  '부실': 3,
#  '임대': 3,
#  '역대': 3,
#  '최대': 3,
#  '기간': 3,
#  '교통': 3,
#  '이하': 3,
#  '입장': 3,
#  '보': 3,
#  '청구': 3,
#  '단장': 3,
#  '늘': 3,
#  '인': 3,
#  '까지': 3,
#  '취지': 3,
#  '막': 3,
#  '제한': 3,
#  '주도': 3,
#  '방침': 3,
#  '율': 3,
#  '경영': 3,
#  '변화': 3,
#  '다만': 3,
#  '회사': 3,
#  '이자': 3,
#  '법안': 3,
#  '일각': 3,
#  '제도': 3,
#  '가맹': 3,
#  '현행': 3,
#  '인터넷': 3,
#  '세제': 3,
#  '가의': 3,
#  '전체': 3,
#  '절반': 3,
#  '당장': 3,
#  '부분': 3,
#  '과표': 3,
#  '초과': 3,
#  '안팎': 3,
#  '순위': 3,
#  '법인': 3,
#  '연구원': 3,
#  '면제': 3,
#  '화제': 3,
#  '왼쪽': 3,
#  '대통령비서실장': 3,
#  '산행': 3,
#  '비서실': 3,
#  '소통': 3,
#  '등산': 3,
#  '이사': 3,
#  '관저': 3,
#  '달라': 3,
#  '건물': 3,
#  '한마디': 3,
#  '영부인': 3,
#  '눈물': 3,
#  '이삿짐': 3,
#  '조금': 3,
#  '직전': 3,
#  '대검찰청': 3,
#  '현직': 3,
#  '금': 3,
#  '봉욱': 3,
#  '분위기': 3,
#  '사법연수원': 3,
#  '사건': 3,
#  '역할': 3,
#  '부장': 3,
#  '행사': 3,
#  '파괴': 3,
#  '전망': 3,
#  '변호사': 3,
#  '기이': 3,
#  '물망': 3,
#  '소병철': 3,
#  '신임': 3,
#  '북핵': 3,
#  '권력': 3,
#  '차기': 3,
#  '유력': 3,
#  '국사': 3,
#  '조광': 3,
#  '학자': 3,
#  '체제': 3,
#  '한국사': 3,
#  '학부': 3,
#  '박사': 3,
#  '국정교과서': 3,
#  '활동': 3,
#  '복안': 3,
#  '참모총장': 3,
#  '해병대': 3,
#  '진영': 3,
#  '비리': 3,
#  '그간': 3,
#  '식': 3,
#  '평': 3,
#  '로부터': 3,
#  '타': 3,
#  '과거': 3,
#  '영입': 3,
#  '겸': 3,
#  '온': 3,
#  '시도': 3,
#  '이유': 3,
#  '상징': 3,
#  '금지': 3,
#  '전면': 3,
#  '적발': 3,
#  '선대': 3,
#  '보고': 3,
#  '광주': 3,
#  '노동조합': 3,
#  '의장': 3,
#  '승희': 3,
#  '세무조사': 3,
#  '그룹': 3,
#  '자기': 3,
#  '가족': 3,
#  '동시': 3,
#  '양성평등': 3,
#  '횡설수설': 3,
#  '부처': 3,
#  '대변인': 3,
#  '대학원': 3,
#  '진정': 3,
#  '기소권': 3,
#  '대한민국': 3,
#  '번': 3,
#  '결심': 3,
#  '구속': 3,
#  '여의도': 3,
#  '회관': 3,
#  '해양수산부': 3,
#  '한나라당': 3,
#  '우리당': 3,
#  '합류': 3,
#  '독수리': 3,
#  '헌법': 3,
#  '군포': 3,
#  '수산': 3,
#  '남성': 3,
#  '첫발': 3,
#  '폭로': 3,
#  '차출': 3,
#  '국토부': 3,
#  '김상조': 3,
#  '분양': 3,
#  '전매': 3,
#  '표결': 3,
#  '불참': 3,
#  '자치': 3,
#  '체육관': 3,
#  '광부': 3,
#  '충북': 3,
#  '청주시': 3,
#  '최순실': 3,
#  '이익': 3,
#  '저': 3,
#  '은': 3,
#  '대신': 3,
#  '거부': 3,
#  '보건복지부': 3,
#  '토론회': 3,
#  '성공': 3,
#  '협상': 3,
#  '전남대': 3,
#  '일어난다': 3,
#  '기성': 3,
#  '채널': 3,
#  '영상': 3,
#  '진입': 3,
#  '격의': 3,
#  '목': 3,
#  '집단': 3,
#  '좌파': 3,
#  '민영화': 3,
#  '박석': 3,
#  '돈키호테': 3,
#  '수가': 3,
#  '협의': 3,
#  '너무': 3,
#  '영리': 3,
#  '자회사': 3,
#  '이해관계': 3,
#  '이미지': 3,
#  '김한길': 3,
#  '발전': 3,
#  '광장': 3,
#  '지지자': 3,
#  '영혼': 3,
#  '허물': 3,
#  '종로구': 3,
#  '만들기': 3,
#  '조언': 3,
#  '라디오': 3,
#  '여론조사': 3,
#  '고문': 3,
#  '일대일': 3,
#  '빌딩': 3,
#  '성명': 3,
#  '철수': 3,
#  '선택': 3,
#  '구태': 3,
#  '공학': 3,
#  '대결': 3,
#  '여망': 3,
#  '강원': 3,
#  '택': 3,
#  '대안': 3,
#  '제보': 3,
#  '조작': 3,
#  '동교동계': 3,
#  '기업인': 3,
#  '창조': 3,
#  '창조경제': 3,
#  '협력': 3,
#  '결집': 3,
#  '초기': 2,
#  '주말': 2,
#  '백악관': 2,
#  '달': 2,
#  '워싱턴': 2,
#  '중국': 2,
#  '일본': 2,
#  '대사': 2,
#  '청와대로': 2,
#  '불똥': 2,
#  '해당': 2,
#  '미리': 2,
#  '개인': 2,
#  '파장': 2,
#  '해촉': 2,
#  '위촉': 2,
#  '차례': 2,
#  '일찌': 2,
#  '감치': 2,
#  '균': 2,
#  '열': 2,
#  '김정은': 2,
#  '포기': 2,
#  '전제': 2,
#  '연쇄': 2,
#  '조명': 2,
#  '세운': 2,
#  '양국': 2,
#  '강경화': 2,
#  '정점': 2,
#  '외교학': 2,
#  '강행': 2,
#  '판단': 2,
#  '후임': 2,
#  '봉합': 2,
#  '상태': 2,
#  '중진': 2,
#  '불': 2,
#  '초점': 2,
#  '대체로': 2,
#  '뉴딜': 2,
#  '눈': 2,
#  '도심': 2,
#  '아파트': 2,
#  '특별법': 2,
#  '살': 2,
#  '마을': 2,
#  '도시': 2,
#  '건설': 2,
#  '업체': 2,
#  '매년': 2,
#  '기금': 2,
#  '공사': 2,
#  '공적': 2,
#  '활성화': 2,
#  '진행': 2,
#  '중이': 2,
#  '마련': 2,
#  '맞춤': 2,
#  '민간': 2}

# %%
nw = "negative-words.txt"
pw = "positive-words.txt"

nw_s = read_file(nw)
pw_s = read_file(pw)

score = 0

# %%
nw_s
# Out:
# {'불명예스럽게',
#  '울트라 - 하드 라인',
#  '복수심으로',
#  '주름진',
#  '묽게 하다',
#  '없어도 되는',
#  '슬픈 듯이',
#  '근거가없는',
#  '장난',
#  '미친 사람',
#  '건망증',
#  '분해하다',
#  '꾸며서',
#  '약 해지는',
#  '사기성',
#  '분명치 않은',
#  '격변 적으로',
#  '혼잡 한',
#  '토우 드리',
#  '애쉬',
#  '자격이없는',
#  '받지 않다',
#  '부지불식간에',
#  '히스테리하게',
#  '울다',
#  '금지적인',
#  '압도적으로',
#  '두려워',
#  '스쿼시',
#  '트위스트',
#  '찌르기',
#  '실종',
#  '눈에 거슬리는',
#  '충동적인',
#  '홍',
#  '황백',
#  '죄',
#  '말다툼하는',
#  '불확실하게',
#  '지구',
#  '좋은 생각',
#  '이기적으로',
#  '폭동',
#  '신통치 않게',
#  '긁어 모으다',
#  '쓸모 없게',
#  '폐색',
#  '득실 거리는',
#  '깜짝 놀라',
#  '급한',
#  '부정하다',
#  '꼬집기',
#  '범죄자',
#  '심연',
#  '비꼬는듯한',
#  '범하다',
#  '일방주의',
#  '암내',
#  '가득 차서',
#  '하위',
#  '침략적인',
#  '오줌 누운',
#  '가난한 사람',
#  '난처하게 여기다',
#  '이중 자물쇠',
#  '비구름',
#  '경외의',
#  '경멸하다',
#  '가능성이없는',
#  '피켓을 입은',
#  '떠드는 소리',
#  '무자비한',
#  '대결적인',
#  '뗄 수없는',
#  '헛된',
#  '노곤한',
#  '걱정하는',
#  '비방',
#  '꽉 무는',
#  '기운 없는',
#  '비 윤리적 인',
#  '성가신',
#  '반점이있는',
#  '신뢰할 수 없는',
#  '미치도록',
#  '냉담하게',
#  '저주 받을 만한',
#  '괴로워하는 사람',
#  '조바심',
#  '말썽 꾸러기',
#  '오해 된',
#  'f ** k',
#  '어려운',
#  '갈퀴',
#  '흐림',
#  '둔감 한',
#  '유적',
#  '서류 미비 자',
#  '사기가 나쁜',
#  '불길한',
#  '대홍수',
#  '희석 - 댈리',
#  '잔인하게',
#  '깜짝 놀라게하는',
#  '비틀다',
#  '병난',
#  '편향',
#  '소음',
#  '과완하다',
#  '끊어진',
#  '조언자',
#  '악마 화하는',
#  '철저한',
#  '부식제',
#  '스캔들하다',
#  '뚱뚱한 고양이',
#  '다스리기 어려운',
#  '더러운 것',
#  '편치 않은',
#  '불투명 한',
#  '없는',
#  '불완전하게',
#  '비논리적 인',
#  '투옥',
#  '지나치게 단순화 된',
#  '고발',
#  '무력감',
#  '거부하다',
#  '멍청한',
#  'f다',
#  '쑥 들어가게 하다',
#  '정통',
#  '그릇된 지도',
#  '위반',
#  '흐린',
#  '내키지 않는',
#  '깜짝 놀라게 하다',
#  '아이러니 한',
#  '현혹 된',
#  '곰팡내 나는',
#  '죄가 많은',
#  '논쟁하는',
#  '교활하게',
#  '녹',
#  '피하다',
#  '아픔',
#  '창백한',
#  '희망없이',
#  '범프',
#  '반항',
#  '위력',
#  '어긋남',
#  '스트레스가 많은',
#  '놀랍게도',
#  '환멸을 느낀',
#  '흐르지 않는',
#  '걸쭉한',
#  '오명',
#  '뒹굴다',
#  '무의식적으로',
#  '동요',
#  '남용',
#  '잃어버린',
#  'sensationalize',
#  '가장 추한',
#  '화장대',
#  '예사롭지 않은',
#  '언더 컷팅',
#  '어린애 같은',
#  '어두운',
#  '야만성',
#  '멋진',
#  '과즙',
#  '견책',
#  '설탕 코트',
#  '경쟁',
#  '차가운',
#  '용납 할 수없는',
#  '선동자',
#  '불연속',
#  '쇠미',
#  '결정되지 않은',
#  '특대',
#  '말다툼',
#  '당혹스럽게',
#  '수동성',
#  '으스스하게',
#  '미친',
#  '고생 한',
#  '기근',
#  '심한 타격을 입은',
#  '몰인정',
#  '부당하게',
#  '반갑지 않은',
#  '홈통',
#  '파산자',
#  '용기를 잃다',
#  '폭도들',
#  '카 푸트',
#  '문제들',
#  'quarrellously',
#  '차별',
#  '창피하다',
#  '싼',
#  '비난하는',
#  '비좁은',
#  '유출',
#  '부패한',
#  '긁힌',
#  '긴장하는',
#  '무 반응의',
#  '깨진',
#  '사생아의',
#  '혼란스러운',
#  '무능력',
#  '위협',
#  '무의미한 말',
#  '글로우',
#  '허위 진술',
#  '볶은 것',
#  '고생',
#  '부인하다',
#  '어기다',
#  '마약 중독자',
#  '흔들리는',
#  '정죄하다',
#  '거지',
#  '커밋',
#  '심술 궂은 사람',
#  '과오',
#  '분출',
#  '맹목적으로하다',
#  '화내는',
#  '검게 하다',
#  '틀림없이',
#  '농담하는 사람',
#  '험준한',
#  '잘못 취급하다',
#  '차별하다',
#  '달래다',
#  '타고 있는',
#  '무단 결석자',
#  '놀리는',
#  '거드름 부리는',
#  '용서가없는',
#  '우연한',
#  '조심성있게',
#  '판다',
#  '퍼지',
#  '한조각',
#  '불법',
#  '대량의',
#  '싫어함',
#  '튀김',
#  '반 우리',
#  '성실하지 않은',
#  '만들다',
#  '경멸적인',
#  '달래기 어려운',
#  '저속한',
#  '험담',
#  '효과적인',
#  '혐의',
#  '쥐 우는 소리',
#  '복수하다',
#  '편협한 신앙',
#  '박편',
#  '부정확하게',
#  '관심사',
#  '올무',
#  '간섭',
#  '되다',
#  '땡땡',
#  '윙크',
#  '방책',
#  '상상할 수없는',
#  '동굴',
#  '자살적인',
#  '뒷걸음질',
#  '조커',
#  '불공평하게',
#  '멸하다',
#  '불변의',
#  '구멍',
#  '악마가되다',
#  '낄낄 거리다',
#  '무심코',
#  '미치게',
#  '편견없는',
#  '몹시 탐내는',
#  '푸주한',
#  '미개한',
#  '스페이드',
#  '모욕하는',
#  '묵시적인',
#  '시장 조작',
#  '싸우다',
#  '민감한',
#  '환각',
#  '격렬하게',
#  '연기',
#  '얽매다',
#  '마비 된',
#  '망치다',
#  '노력',
#  '비생산적인',
#  '블러 링',
#  '단음',
#  '손실',
#  '우울한',
#  '비판',
#  '부끄러움',
#  '고의적 인',
#  '불법의',
#  '완고한',
#  '음탕 한',
#  '가증스러운',
#  '안된다고 하다',
#  '유감',
#  '광신적 인',
#  '지치지 않는',
#  '못된',
#  '우는 소리',
#  '칼',
#  '지루한',
#  '사취',
#  '우습고 재미있게',
#  '과소 평가하다',
#  '골',
#  '가장 느린',
#  '무기한으로',
#  'g아 먹는',
#  '도전하다',
#  '부족한 거스름 돈',
#  '불경스럽게',
#  '정리 해고',
#  '펀치',
#  '곪다',
#  '양립 할 수없는',
#  '욕심',
#  '단골 손님',
#  '소환장',
#  '엄한',
#  '핫 헤드드',
#  '독사 같은 사람',
#  '주입',
#  '성 잘 내는',
#  '동정',
#  '애매',
#  '바이러스',
#  '푼',
#  '불결한',
#  '까다로운',
#  '괴로워하는',
#  '슬프게',
#  '망상의',
#  '잔인 함',
#  '보다 나쁜',
#  '아프다',
#  '껄끄 러운',
#  '기분 나쁜',
#  '포석 포장',
#  '유니 폴라',
#  '해체 된',
#  '소 칼',
#  '탁탁 소리',
#  '참견 잘하는',
#  '방치 된',
#  '멜로 드라마틱 한',
#  '억압',
#  '머리통',
#  '비틀기',
#  '가시',
#  '불순종',
#  '불결',
#  '저더',
#  '희미하게',
#  '승자',
#  '황소*',
#  '부주의 한',
#  '주저하는',
#  '피켓',
#  '주먹',
#  '강경파',
#  '유명한',
#  '격퇴',
#  '짜증나게 하다',
#  '추잡한',
#  '옴폭 들어간 곳',
#  '왕겨',
#  '부당한 대우를받은',
#  '자백',
#  '속이기',
#  '역겨운',
#  '억제',
#  '짜증 나는',
#  '꾸민',
#  '부실',
#  '마루의',
#  '방랑자',
#  '비참한',
#  '항복',
#  '댐퍼',
#  '악명 높은',
#  '두근 거리는',
#  '비타협적 인',
#  '보온재',
#  '대담한',
#  '유언',
#  '지나치게 과장된',
#  '참다',
#  '위태롭게 하다',
#  '부당한 대우',
#  '불법적으로',
#  '현기증 나는',
#  '괴롭히는',
#  '아이러니',
#  '낙오자',
#  '부피',
#  '외설스럽게',
#  '환각시키다',
#  '어찌할 수 없는',
#  '너무 삶은',
#  '수가 막힘',
#  '비장',
#  '어두워 진',
#  '강박적인',
#  '반대자',
#  '우울',
#  '많은',
#  '스튜',
#  '위축',
#  '어쩔 수없이',
#  '동의하지 않는다',
#  '고충',
#  '필사적 인',
#  '유해한',
#  '열정적으로',
#  '오용',
#  '경련',
#  '약화',
#  '쐐기풀',
#  '놈',
#  '눈사태',
#  '피하는',
#  '갈등 한',
#  '견딜 수 없기',
#  '불쾌한 사람',
#  '단 정치 못한',
#  '뻔뻔한',
#  '하드 향하고',
#  '안개',
#  '터무니없는',
#  '의뢰서',
#  '침몰 한',
#  '없음 \\ EFve',
#  '연마제',
#  '범람하다',
#  '겁 먹게하다',
#  '포',
#  '더 부자 인',
#  '방해',
#  '위선적으로',
#  'immoderately',
#  '감각이없는',
#  '곤란',
#  '폭군',
#  '혼잡함',
#  '감소',
#  '만족할 줄 모르는',
#  '무책임하게',
#  '비누',
#  '온상',
#  '입을 크게 벌리다',
#  '품위 없는',
#  '악화시키는',
#  '연기가 나는',
#  '역경',
#  '부서진',
#  '크레이븐',
#  '부적절한 사용',
#  '가난한',
#  '바람둥이',
#  '양극화',
#  '복잡한',
#  '그루터기',
#  '가망 없음',
#  '악독',
#  '괴롭히다',
#  '유쾌하게',
#  '모욕적으로',
#  '박해',
#  '운명적으로',
#  '하찮아 보이게 만들다',
#  '참을성이없는',
#  '비관적으로',
#  '비교할 수 없는',
#  '쐐기',
#  '복마전',
#  '실업자',
#  '불임',
#  '강하게 하다',
#  '중상',
#  '부당',
#  '증후군',
#  '분노한',
#  '불평',
#  '위협적으로',
#  '틀린',
#  '어리석게',
#  '맞지 않는 옷',
#  '획기적인',
#  '일방적 인',
#  '장력',
#  '숟가락 먹이로 한',
#  '짐승',
#  '짐승 같은',
#  '꾸지람',
#  '삐걱 거리는 소리',
#  '미적지근한',
#  '전제 군주',
#  '가슴 아픈',
#  '발행물',
#  '연체 된',
#  '쉬 * t',
#  '무시 무시하게',
#  '이단의',
#  '조증의',
#  '한정',
#  '파괴자',
#  '애호가',
#  '우울하게',
#  '폐허',
#  '음탕함',
#  '다시 기록 된',
#  '갑자기',
#  '깜짝 놀람',
#  '병',
#  '잘난 체하는',
#  '조롱을당한',
#  '화해 할 수없는',
#  '왜곡 된',
#  '황달',
#  '긁다',
#  '당황케 하다',
#  '엎드려서',
#  '전제국',
#  '저주 받은',
#  '애새끼',
#  '도전적으로',
#  '격분시키는',
#  '무례',
#  '알레르기',
#  '지킬 수 없는',
#  '기이 한 일',
#  '무모함',
#  '천박하게',
#  '비정상',
#  '더듬 거리는 소리',
#  '공격하다',
#  '차이',
#  '외상성의',
#  '찌꺼기',
#  '과다한',
#  '더 추악한',
#  '빌리안',
#  '뒤집어 엎다',
#  '야만 상태',
#  'unproves',
#  '누를 수 없는',
#  '더 두꺼운',
#  '특히',
#  '해체자',
#  '말린 고기',
#  '귀찮음',
#  '불명확 한',
#  '실수',
#  '움푹 패인',
#  '경비',
#  '앉기 불편한',
#  '죽이는',
#  '스며들게 하다',
#  '기가 죽은',
#  '패자',
#  '유독 한',
#  '지방이 많은',
#  '공격',
#  '죽다',
#  '소원',
#  '기력',
#  '호되게 꾸짖다',
#  '서리',
#  '초조',
#  '실향민',
#  '여러 가지 잡다한',
#  '무조건적으로',
#  '퇴행성의',
#  '어둡게 하다',
#  '어리둥절하게하는',
#  '비실용적 인',
#  '비인간 화',
#  '기만',
#  '라메',
#  '소송중인',
#  '섬광',
#  '미혹',
#  '생략하다',
#  '외딴',
#  '~시키다',
#  '거절 한',
#  '배은망덕',
#  '헤 클스',
#  '쓰라린',
#  '살인자',
#  '괴롭힘',
#  '절박',
#  '불편',
#  '무차별의',
#  '마구 자르기',
#  '표저',
#  '굴욕',
#  '무의식의',
#  '스매시',
#  '성급한 사람',
#  '도전',
#  '불명예',
#  '단조로운',
#  '건방진',
#  '점착제',
#  '구실',
#  '요통',
#  '부주의',
#  '부정한',
#  'inconsolably',
#  '부끄럽게',
#  '난처한',
#  '투옥하다',
#  '참을성있게',
#  '어울리지 않는',
#  '뒤쥐',
#  '흠집',
#  '테러 유전자',
#  '순교',
#  '냉기',
#  '신경 질적으로',
#  '우려',
#  '신비화하다',
#  '계속해',
#  '레치',
#  '해체하다',
#  '붙어있는',
#  '불요 불굴',
#  '달다',
#  '조금도',
#  '시험',
#  '아시아 인',
#  '잘못한',
#  '악의 없는 거짓말',
#  '밀행',
#  '노곤함',
#  '고통스러운',
#  '와해',
#  '문제가있는',
#  '불리한',
#  '반 이스라엘',
#  '애매한 말',
#  '단순한',
#  '고문으로',
#  '도망하다',
#  '흔들린',
#  '잔혹한',
#  '나무랄 만한',
#  '어리 석다',
#  '위반자',
#  '복잡한 줄 거리',
#  '믿지 못할',
#  '우스운',
#  '정복',
#  '직면',
#  '레몬',
#  '오판',
#  '덜 발달 된',
#  '문제 삼다',
#  '장애물',
#  '비합리적인',
#  '포학',
#  '끊다',
#  '따돌림',
#  '길항근',
#  '복수심 있는',
#  '모순',
#  '악마가 된',
#  '후회스러운',
#  '무능한',
#  '지키기 어려운',
#  '낙담하게',
#  '암살하다',
#  '겁없는',
#  '성나게 하기',
#  '비벼서 따뜻하게 하다',
#  '장황한',
#  '피할 수 없는',
#  '나쁘게',
#  '꼭두각시',
#  '위조하다',
#  '비꼬는',
#  '견고성',
#  '대법원의',
#  '과대 평가',
#  '격렬히',
#  '곤충',
#  '다투다',
#  '불만 사항',
#  '비열한',
#  '시기심',
#  '전복 적으로',
#  '연기가 자욱한',
#  '비명',
#  '불충실 한',
#  '불완전',
#  '알아볼 수없는',
#  '잘못 발음하다',
#  '탐욕스러운',
#  '비신경',
#  '지나치게 뻗다',
#  '한정된',
#  '물 부족',
#  '보람 없는',
#  '지루하게',
#  '슬픈',
#  '펄쩍 뛸 만한 놀람',
#  '소름 끼치게하다',
#  '지혜 없는',
#  '미프',
#  '겸손한',
#  '팬',
#  '기질',
#  '할 수 없는',
#  '오도',
#  '자만심이 강한',
#  '황폐화하다',
#  '불완전한',
#  '무서운',
#  '부도덕',
#  '물집',
#  '레일',
#  '반역',
#  '양면의',
#  '돌이킬 수없는',
#  '날카로운',
#  '꾸짖다',
#  '결함 있는',
#  '일축',
#  '활동하지 않은',
#  '큰 파란',
#  '비관적 인',
#  '속임수',
#  '비우다',
#  '어색한',
#  '역재',
#  '싫음',
#  '그릇되게',
#  '강경히',
#  's 거리는 소리',
#  '외로움',
#  '불순종 한',
#  '보어',
#  '무적의',
#  '야만인 같게',
#  '헛소리',
#  '별난',
#  'calumnies',
#  '태만',
#  '격변',
#  '얼빠진',
#  '돌발',
#  '변형 된',
#  '스캔들',
#  '잘못 전하다',
#  '진압',
#  '울퉁불퉁 한',
#  '변태',
#  '지겨운',
#  '품위를 떨어 뜨리는',
#  '함축',
#  '나쁜 길로 이끌다',
#  '조각난',
#  '격노 한',
#  '지정되지 않은',
#  '쥐',
#  '잊기 쉬운',
#  '알아들을 수 없는 빠른 말',
#  '배신하다',
#  '달성 할 수없는',
#  '강제력',
#  '해를 끼치다',
#  '심한',
#  '비교할 수없는',
#  '얇은',
#  '부족하다',
#  '얽힌',
#  '부딪친',
#  '오해 할 정도로',
#  '항 증식',
#  '신화',
#  '불 태우다',
#  '괴롭힘을당한',
#  '억제 되지 않은',
#  '완전히',
#  '극악한',
#  '뚱뚱한 사람',
#  '버기',
#  '실망스런',
#  '인사',
#  '몸이 좋지 않다',
#  '격퇴하는',
#  '독재적인',
#  '비난하게',
#  '기다',
#  '분개 한',
#  '해체',
#  '비 효과적으로',
#  '창백하게',
#  '지독한 시련',
#  '전복',
#  '불화',
#  '하찮게',
#  '잴 수 없는',
#  '꺼내다',
#  '언쟁',
#  '감옥',
#  '다툼의',
#  '경멸하는',
#  '노인',
#  '불만',
#  '거칠게',
#  '살해 된',
#  '다중 분극',
#  '빨판',
#  '오싹하다',
#  '황폐',
#  '딱딱한',
#  '잔인한 짓',
#  '외치다',
#  '파시스트 당원',
#  '불확정의',
#  '중대한',
#  '낭비',
#  '~을',
#  '매력없는',
#  '분해되지 않은',
#  '교전국',
#  '침대',
#  '단념시키다',
#  '만성병 환자',
#  '비협조적 인',
#  '플레어',
#  '구역질 나는',
#  '떠드는',
#  '못쓰게 만들다',
#  '슬픔',
#  '파국적 인',
#  '아픈 사람',
#  '농담',
#  '쓸 수 없는',
#  '보험에 들지 않은',
#  '작은',
#  '쿠데타',
#  '가려움증',
#  '원한',
#  '훈계로',
#  '숨기다',
#  '믿을 수 없는',
#  '거만한',
#  '여비',
#  '악몽',
#  '더 부피가 큰',
#  '경보',
#  '냉소적',
#  '암살자',
#  '비효율적으로',
#  '자기 비판',
#  '2면',
#  '콘 덴스',
#  '게으른',
#  '반하는',
#  '협박하는',
#  '짜증 난다.',
#  '폭압으로',
#  '읽을 수없는',
#  '여읨',
#  '무자비하게',
#  '압박',
#  '깜짝 놀라게 하는',
#  '야만인',
#  '엄격',
#  '감시',
#  '크기가 작은',
#  '덫을 놓은',
#  '레임덕',
#  '불행한',
#  '헛소리하는',
#  '구부러진',
#  '매서운',
#  '과장되게',
#  '반대로',
#  '하찮은',
#  '덜컹 거리는 소리',
#  '나쁜 평판',
#  '상해',
#  '징계하다',
#  '무트',
#  '삼림지',
#  '사망 한',
#  '쑥스럽게',
#  '마더',
#  '삐걱 거리다',
#  '고행',
#  '불공정 한',
#  '대수롭지 않은',
#  '반사회적인',
#  '처벌 할 수있는',
#  '반항적 인',
#  '남풍',
#  '찌는듯한',
#  '찍찍 소리 내는',
#  '다루기 어려운',
#  '장난스럽게',
#  '추락 한',
#  '고글',
#  '냄새',
#  '음흉하게하다',
#  '불평하다',
#  '냄새 나는',
#  '슬럼프',
#  '술집',
#  '변형',
#  '전쟁과 같은',
#  '끽끽 우는 소리',
#  '줄진',
#  '굴욕적인',
#  '응징',
#  '뻔뻔 스러움',
#  '가져 오기',
#  '단정 한',
#  '바보',
#  '방탕',
#  '말더듬는 소리',
#  '믿지 않는 사람',
#  '내리 누르다',
#  '악명 높게',
#  '누출',
#  '덜컥 거리는',
#  '논박하는',
#  '피곤한',
#  '피곤하게',
#  '무면허의',
#  '슬퍼하는',
#  '긴급한',
#  '슬퍼서',
#  '생생하게',
#  '지체',
#  '존재하지 않는',
#  '멜로 드라마틱하게',
#  '버그',
#  '그늘진',
#  '기분 전환',
#  '스음',
#  '찌르다',
#  '스테레오',
#  '졸졸하는',
#  '반복적 인',
#  '거세 된',
#  '호색가',
#  '잡아 비틀다',
#  '외설',
#  '징벌 적',
#  '위험한',
#  '물들이는',
#  '중단',
#  '유혈',
#  '어둠',
#  '불쾌한',
#  '제국주의 자',
#  '혼란스럽게하는',
#  '부피가 큰',
#  '충격적인',
#  '사악한 행위',
#  '상상할 수 없는',
#  '비난',
#  '쏘는',
#  '더러움',
#  '헤로인',
#  '경시 된',
#  '신음 소리',
#  '마비시키다',
#  '불충 한',
#  '흐르지 않다',
#  '귀가 먹은',
#  '현기증',
#  ...}

# %%
a = {"나는":2,"비방":4,"복수하다":100,"행복":3,"축복":5,"지적인":13}

# %%
test
# Out:
# {'대통령': 190,
#  '것': 131,
#  '전': 124,
#  '안': 117,
#  '문재인': 103,
#  '안철수': 93,
#  '의원': 86,
#  '고': 83,
#  '후보': 80,
#  '장관': 77,
#  '일': 74,
#  '민주당': 74,
#  '기사': 73,
#  '문': 70,
#  '정부': 69,
#  '후보자': 68,
#  '년': 68,
#  '전술핵': 62,
#  '추천': 60,
#  '정치': 57,
#  '김': 57,
#  '대표': 56,
#  '등': 53,
#  '관련': 49,
#  '창': 49,
#  '수': 48,
#  '만': 48,
#  '인사': 45,
#  '카드': 44,
#  '미국': 41,
#  '기자': 40,
#  '배치': 39,
#  '국민': 39,
#  '개혁': 39,
#  '대선': 39,
#  '검찰': 39,
#  '위원장': 38,
#  '사설': 38,
#  '그': 38,
#  '이': 36,
#  '정책': 36,
#  '재': 36,
#  '우리': 35,
#  '청와대': 34,
#  '며': 34,
#  '론': 34,
#  '압박': 34,
#  '김순덕': 34,
#  '대북': 33,
#  '운동': 33,
#  '개월': 33,
#  '뉴스': 32,
#  '칼럼': 32,
#  '순': 32,
#  '비수': 32,
#  '제재': 31,
#  '원장': 31,
#  '반도': 31,
#  '숙명': 31,
#  '따윈': 31,
#  '무기': 31,
#  '한반도': 31,
#  '박지원': 31,
#  '내각': 31,
#  '베스트': 30,
#  '전자': 30,
#  '장비': 30,
#  '먹통': 30,
#  '공': 30,
#  '박정희': 30,
#  '기념우표': 30,
#  '발행': 30,
#  '촉구': 30,
#  '서명': 30,
#  '조': 30,
#  '수석': 30,
#  '새': 29,
#  '건': 28,
#  '안보': 27,
#  '때': 27,
#  '원': 27,
#  '단일': 27,
#  '출마': 27,
#  '외교': 26,
#  '날': 26,
#  '출신': 26,
#  '정당': 26,
#  '신당': 26,
#  '를': 25,
#  '더': 25,
#  '문제': 24,
#  '뒤': 24,
#  '한국': 23,
#  '보기': 23,
#  '민주': 23,
#  '지방선거': 23,
#  '회장': 22,
#  '임명': 22,
#  '연대': 22,
#  '서울': 21,
#  '명': 21,
#  '공약': 21,
#  '혁신': 21,
#  '여사': 20,
#  '노무현': 20,
#  '월': 20,
#  '가능성': 20,
#  '국회': 20,
#  '소득': 19,
#  '차관': 19,
#  '교육': 19,
#  '새정치': 19,
#  '선거': 19,
#  '국세청': 19,
#  '특보': 18,
#  '최고': 18,
#  '지역': 18,
#  '대한': 18,
#  '씨': 18,
#  '진보': 18,
#  '총장': 18,
#  '교육감': 18,
#  '야권': 18,
#  '교수': 17,
#  '말': 17,
#  '라며': 17,
#  '당선': 17,
#  '중심': 16,
#  '사실': 16,
#  '통해': 16,
#  '로': 16,
#  '점': 16,
#  '사회': 16,
#  '대해': 15,
#  '또': 15,
#  '의사': 15,
#  '의': 15,
#  '세율': 15,
#  '때문': 15,
#  '공동': 15,
#  '문화': 15,
#  '세력': 15,
#  '후': 14,
#  '사드': 14,
#  '실장': 14,
#  '이번': 14,
#  '경제': 14,
#  '위해': 14,
#  '선': 14,
#  '인상': 14,
#  '박근혜': 14,
#  '반대': 14,
#  '자신': 14,
#  '검찰총장': 14,
#  '국정': 14,
#  '국방': 14,
#  '당': 14,
#  '관': 13,
#  '사람': 13,
#  '관계자': 13,
#  '사의': 13,
#  '위원': 13,
#  '의료': 13,
#  '게': 13,
#  '당시': 13,
#  '지명': 13,
#  '서울대': 13,
#  '조사': 13,
#  '통합': 13,
#  '우려': 12,
#  '데': 12,
#  '상황': 12,
#  '책임': 12,
#  '제': 12,
#  '주의': 12,
#  '손': 12,
#  '첫': 12,
#  '비서': 12,
#  '법무부': 12,
#  '여성': 12,
#  '정치인': 12,
#  '양': 12,
#  '노환규': 12,
#  '차장': 11,
#  '발언': 11,
#  '중': 11,
#  '층': 11,
#  '임대주택': 11,
#  '법인세': 11,
#  '기업': 11,
#  '료': 11,
#  '도입': 11,
#  '결정': 11,
#  '수도': 11,
#  '위원회': 11,
#  '인선': 11,
#  '기': 11,
#  '현역': 11,
#  '새누리당': 11,
#  '라인': 10,
#  '회의': 10,
#  '분석': 10,
#  '에서': 10,
#  '전문가': 10,
#  '사업': 10,
#  '센터': 10,
#  '연': 10,
#  '채': 10,
#  '금리': 10,
#  '내': 10,
#  '대기업': 10,
#  '법무': 10,
#  '박': 10,
#  '부산': 10,
#  '정치권': 10,
#  '총선': 10,
#  '블랙리스트': 10,
#  '및': 9,
#  '정상회담': 9,
#  '구조': 9,
#  '다른': 9,
#  '홍': 9,
#  '앞': 9,
#  '의지': 9,
#  '방향': 9,
#  '도시재생': 9,
#  '우선': 9,
#  '억': 9,
#  '지원': 9,
#  '전국': 9,
#  '총량': 9,
#  '관리': 9,
#  '경우': 9,
#  '방안': 9,
#  '라면': 9,
#  '이후': 9,
#  '조직': 9,
#  '사퇴': 9,
#  '통화': 9,
#  '연합': 9,
#  '지지': 9,
#  '시절': 9,
#  '조국': 9,
#  '민정': 9,
#  '김부겸': 9,
#  '김영춘': 9,
#  '도종환': 9,
#  '국민의당': 9,
#  '시간': 8,
#  '한미': 8,
#  '크게': 8,
#  '자리': 8,
#  '내용': 8,
#  '생각': 8,
#  '시대': 8,
#  '시장': 8,
#  '기존': 8,
#  '주택': 8,
#  '곳': 8,
#  '구상': 8,
#  '공공': 8,
#  '교체': 8,
#  '공급': 8,
#  '뜻': 8,
#  '대출': 8,
#  '추진': 8,
#  '연구': 8,
#  '부담': 8,
#  '법': 8,
#  '분': 8,
#  '세금': 8,
#  '현실': 8,
#  '얘기': 8,
#  '배': 8,
#  '검': 8,
#  '발탁': 8,
#  '의혹': 8,
#  '고려대': 8,
#  '평가': 8,
#  '무': 8,
#  '캠프': 8,
#  '해군': 8,
#  '일이': 8,
#  '다시': 8,
#  '과정': 8,
#  '김상곤': 8,
#  '경기도': 8,
#  '관료': 8,
#  '처': 8,
#  '만큼': 8,
#  '서울시장': 8,
#  '듯': 8,
#  '벤처기업': 8,
#  '무소속': 8,
#  '선언': 8,
#  '강연': 8,
#  '합당': 8,
#  '두': 7,
#  '중앙': 7,
#  '정': 7,
#  '외부': 7,
#  '임기': 7,
#  '직접': 7,
#  '못': 7,
#  '줄': 7,
#  '준비': 7,
#  '부동산': 7,
#  '노': 7,
#  '재원': 7,
#  '계획': 7,
#  '집': 7,
#  '일자리': 7,
#  '비': 7,
#  '부채': 7,
#  '개편': 7,
#  '단계': 7,
#  '시': 7,
#  '대책': 7,
#  '여': 7,
#  '대법원': 7,
#  '거론': 7,
#  '제기': 7,
#  '업무': 7,
#  '지금': 7,
#  '국회의원': 7,
#  '국장': 7,
#  '측': 7,
#  '김현미': 7,
#  '로서': 7,
#  '감': 7,
#  '타이밍': 7,
#  '결과': 7,
#  '의협': 7,
#  '논설': 7,
#  '범': 7,
#  '당내': 7,
#  '취임': 6,
#  '초': 6,
#  '서관': 6,
#  '체계': 6,
#  '관계': 6,
#  '제대로': 6,
#  '표명': 6,
#  '간': 6,
#  '주거': 6,
#  '주거지': 6,
#  '수준': 6,
#  '산업': 6,
#  '개': 6,
#  '목표': 6,
#  '가계부채': 6,
#  '청년': 6,
#  '축소': 6,
#  '회': 6,
#  '금융': 6,
#  '빚': 6,
#  '책': 6,
#  '핵심': 6,
#  '한편': 6,
#  '지난': 6,
#  '볼': 6,
#  '건강': 6,
#  '증세': 6,
#  '소득세': 6,
#  '일단': 6,
#  '국가': 6,
#  '신': 6,
#  '오후': 6,
#  '약속': 6,
#  '내부': 6,
#  '걸': 6,
#  '정도': 6,
#  '발표': 6,
#  '교과서': 6,
#  '교육부': 6,
#  '국방부': 6,
#  '현': 6,
#  '반발': 6,
#  '청문회': 6,
#  '인물': 6,
#  '모두': 6,
#  '반': 6,
#  '운영': 6,
#  '탈세': 6,
#  '대통': 6,
#  '합': 6,
#  '위기': 6,
#  '지방': 6,
#  '질문': 6,
#  '김수남': 6,
#  '수사': 6,
#  '수사권': 6,
#  '경찰': 6,
#  '바람': 6,
#  '시인': 6,
#  '입각': 6,
#  '모든': 6,
#  '정권': 6,
#  '과연': 6,
#  '독자': 6,
#  '기득권': 6,
#  '분열': 6,
#  '동물원': 6,
#  '속': 5,
#  '처음': 5,
#  '부인': 5,
#  '논란': 5,
#  '공석': 5,
#  '강': 5,
#  '분야': 5,
#  '고위': 5,
#  '셈': 5,
#  '이상': 5,
#  '일정': 5,
#  '여당': 5,
#  '방법': 5,
#  '안정': 5,
#  '확보': 5,
#  '가장': 5,
#  '먼저': 5,
#  '지난해': 5,
#  '노후': 5,
#  '자산': 5,
#  '중소': 5,
#  '현재': 5,
#  '급': 5,
#  '기본': 5,
#  '폐지': 5,
#  '과제': 5,
#  '법정': 5,
#  '가계': 5,
#  '비율': 5,
#  '속도': 5,
#  '규제': 5,
#  '그동안': 5,
#  '확대': 5,
#  '조정': 5,
#  '추가': 5,
#  '검토': 5,
#  '언급': 5,
#  '대부분': 5,
#  '주장': 5,
#  '유권자': 5,
#  '뿐': 5,
#  '김정숙': 5,
#  '오전': 5,
#  '자택': 5,
#  '대검': 5,
#  '검사': 5,
#  '각각': 5,
#  '돈': 5,
#  '최': 5,
#  '성향': 5,
#  '판사': 5,
#  '최근': 5,
#  '위반': 5,
#  '이낙연': 5,
#  '총리': 5,
#  '대법관': 5,
#  '통한': 5,
#  '인준': 5,
#  '송영': 5,
#  '검증': 5,
#  '거듭': 5,
#  '방어': 5,
#  '부총리': 5,
#  '학교': 5,
#  '재직': 5,
#  '전격': 5,
#  '도전': 5,
#  '사과': 5,
#  '정국': 5,
#  '강화': 5,
#  '박원순': 5,
#  '풀이': 5,
#  '공수': 5,
#  '권한': 5,
#  '합의': 5,
#  '바로': 5,
#  '길': 5,
#  '비판': 5,
#  '일부': 5,
#  '친': 5,
#  '칼': 5,
#  '타파': 5,
#  '탈당': 5,
#  '호남': 5,
#  '벽': 5,
#  '선수': 5,
#  '예술': 5,
#  '안배': 5,
#  '체육': 5,
#  '쇄신': 5,
#  '모습': 5,
#  '민생': 5,
#  '격진': 5,
#  '투쟁': 5,
#  '거': 5,
#  '얼마나': 5,
#  '구현': 5,
#  '바보': 5,
#  '기초': 5,
#  '박성원': 5,
#  '난맥': 4,
#  '트럼프': 4,
#  '오른쪽': 4,
#  '특별': 4,
#  '사태': 4,
#  '석비': 4,
#  '명의': 4,
#  '연세대': 4,
#  '도움': 4,
#  '직후': 4,
#  '몇': 4,
#  '적': 4,
#  '개입': 4,
#  '반영': 4,
#  '차': 4,
#  '외교부': 4,
#  '더욱': 4,
#  '각종': 4,
#  '한상준': 4,
#  '믹스': 4,
#  '성': 4,
#  '전통': 4,
#  '규모': 4,
#  '예산': 4,
#  '총': 4,
#  '이전': 4,
#  '질': 4,
#  '시한': 4,
#  '폭탄': 4,
#  '김진표': 4,
#  '브레인': 4,
#  '성장': 4,
#  '효과': 4,
#  '대전': 4,
#  '보호': 4,
#  '긴장': 4,
#  '실현': 4,
#  '장기': 4,
#  '바': 4,
#  '경기': 4,
#  '감안': 4,
#  '서민': 4,
#  '입': 4,
#  '해결': 4,
#  '공식': 4,
#  '하나': 4,
#  '윤': 4,
#  '와': 4,
#  '주기': 4,
#  '보험': 4,
#  '전문': 4,
#  '고액': 4,
#  '부자': 4,
#  '갈등': 4,
#  '오히려': 4,
#  '경쟁': 4,
#  '홍은동': 4,
#  '호소': 4,
#  '하자': 4,
#  '사진': 4,
#  '경선': 4,
#  '북한': 4,
#  '미사일': 4,
#  '상임': 4,
#  '임종석': 4,
#  '임': 4,
#  '조현': 4,
#  '옥': 4,
#  '김경수': 4,
#  '대구': 4,
#  '진': 4,
#  '인천': 4,
#  '포석': 4,
#  '모임': 4,
#  '간사': 4,
#  '법원행정처': 4,
#  '반응': 4,
#  '기수': 4,
#  '간부': 4,
#  '수장': 4,
#  '치': 4,
#  '동아일보': 4,
#  '물': 4,
#  '탄핵': 4,
#  '준': 4,
#  '장': 4,
#  '편찬': 4,
#  '사학': 4,
#  '역사': 4,
#  '석': 4,
#  '운': 4,
#  '친문': 4,
#  '절대': 4,
#  '참여': 4,
#  '송': 4,
#  '하되': 4,
#  '주변': 4,
#  '군': 4,
#  '과': 4,
#  '본부장': 4,
#  '경북': 4,
#  '필요': 4,
#  '참모': 4,
#  '오랫동안': 4,
#  '무상급식': 4,
#  '총학생회': 4,
#  '경영학': 4,
#  '전교조': 4,
#  '공천': 4,
#  '지능': 4,
#  '보궐선거': 4,
#  '당권': 4,
#  '주자': 4,
#  '경력': 4,
#  '본부': 4,
#  '간섭': 4,
#  '이기': 4,
#  '행정자치부': 4,
#  '표정': 4,
#  '끝': 4,
#  '단체': 4,
#  '정무': 4,
#  '해양': 4,
#  '접시꽃': 4,
#  '당신': 4,
#  '돌파': 4,
#  '문체부': 4,
#  '도': 4,
#  '위': 4,
#  '기자회견': 4,
#  '권리': 4,
#  '물론': 4,
#  '알': 4,
#  '회동': 4,
#  '지지율': 4,
#  '반드시': 4,
#  '힘': 4,
#  '파업': 4,
#  '명분': 4,
#  '실제': 4,
#  '전의총': 4,
#  '공감': 4,
#  '통합신당': 4,
#  '국본': 4,
#  '꿈': 4,
#  '스포트라이트': 4,
#  '가치': 4,
#  '눈앞': 4,
#  '설': 4,
#  '측은': 4,
#  '방법론': 4,
#  '비상': 4,
#  '구도': 4,
#  '친구': 4,
#  '미래': 4,
#  '스스로': 4,
#  '논의': 4,
#  '뉴시스': 3,
#  '문정인': 3,
#  '공개': 3,
#  '신설': 3,
#  '국가안보실': 3,
#  '경험': 3,
#  '잡음': 3,
#  '지난달': 3,
#  '명예': 3,
#  '고고': 3,
#  '미사일방어': 3,
#  '본인': 3,
#  '이야기': 3,
#  '사전': 3,
#  '관측': 3,
#  '열흘': 3,
#  '통일부': 3,
#  '실무': 3,
#  '의견': 3,
#  '당초': 3,
#  '영향력': 3,
#  '전날': 3,
#  '무대': 3,
#  '의미': 3,
#  '성과': 3,
#  '목소리': 3,
#  '개발': 3,
#  '환경': 3,
#  '구체': 3,
#  '달성': 3,
#  '행보': 3,
#  '재개발': 3,
#  '차별': 3,
#  '국토교통부': 3,
#  '기준': 3,
#  '정비': 3,
#  '적지': 3,
#  '재정': 3,
#  '원대': 3,
#  '국토': 3,
#  '대상': 3,
#  '시행': 3,
#  '주민': 3,
#  '저울': 3,
#  '이용섭': 3,
#  '조윤제': 3,
#  '홍종학': 3,
#  '분수': 3,
#  '환': 3,
#  '협치': 3,
#  '시험대': 3,
#  '골목': 3,
#  '상권': 3,
#  '대형': 3,
#  '유통업체': 3,
#  '휴대전화': 3,
#  '혹시': 3,
#  '포스코': 3,
#  '대우조선': 3,
#  '회생': 3,
#  '부실': 3,
#  '임대': 3,
#  '역대': 3,
#  '최대': 3,
#  '기간': 3,
#  '교통': 3,
#  '이하': 3,
#  '입장': 3,
#  '보': 3,
#  '청구': 3,
#  '단장': 3,
#  '늘': 3,
#  '인': 3,
#  '까지': 3,
#  '취지': 3,
#  '막': 3,
#  '제한': 3,
#  '주도': 3,
#  '방침': 3,
#  '율': 3,
#  '경영': 3,
#  '변화': 3,
#  '다만': 3,
#  '회사': 3,
#  '이자': 3,
#  '법안': 3,
#  '일각': 3,
#  '제도': 3,
#  '가맹': 3,
#  '현행': 3,
#  '인터넷': 3,
#  '세제': 3,
#  '가의': 3,
#  '전체': 3,
#  '절반': 3,
#  '당장': 3,
#  '부분': 3,
#  '과표': 3,
#  '초과': 3,
#  '안팎': 3,
#  '순위': 3,
#  '법인': 3,
#  '연구원': 3,
#  '면제': 3,
#  '화제': 3,
#  '왼쪽': 3,
#  '대통령비서실장': 3,
#  '산행': 3,
#  '비서실': 3,
#  '소통': 3,
#  '등산': 3,
#  '이사': 3,
#  '관저': 3,
#  '달라': 3,
#  '건물': 3,
#  '한마디': 3,
#  '영부인': 3,
#  '눈물': 3,
#  '이삿짐': 3,
#  '조금': 3,
#  '직전': 3,
#  '대검찰청': 3,
#  '현직': 3,
#  '금': 3,
#  '봉욱': 3,
#  '분위기': 3,
#  '사법연수원': 3,
#  '사건': 3,
#  '역할': 3,
#  '부장': 3,
#  '행사': 3,
#  '파괴': 3,
#  '전망': 3,
#  '변호사': 3,
#  '기이': 3,
#  '물망': 3,
#  '소병철': 3,
#  '신임': 3,
#  '북핵': 3,
#  '권력': 3,
#  '차기': 3,
#  '유력': 3,
#  '국사': 3,
#  '조광': 3,
#  '학자': 3,
#  '체제': 3,
#  '한국사': 3,
#  '학부': 3,
#  '박사': 3,
#  '국정교과서': 3,
#  '활동': 3,
#  '복안': 3,
#  '참모총장': 3,
#  '해병대': 3,
#  '진영': 3,
#  '비리': 3,
#  '그간': 3,
#  '식': 3,
#  '평': 3,
#  '로부터': 3,
#  '타': 3,
#  '과거': 3,
#  '영입': 3,
#  '겸': 3,
#  '온': 3,
#  '시도': 3,
#  '이유': 3,
#  '상징': 3,
#  '금지': 3,
#  '전면': 3,
#  '적발': 3,
#  '선대': 3,
#  '보고': 3,
#  '광주': 3,
#  '노동조합': 3,
#  '의장': 3,
#  '승희': 3,
#  '세무조사': 3,
#  '그룹': 3,
#  '자기': 3,
#  '가족': 3,
#  '동시': 3,
#  '양성평등': 3,
#  '횡설수설': 3,
#  '부처': 3,
#  '대변인': 3,
#  '대학원': 3,
#  '진정': 3,
#  '기소권': 3,
#  '대한민국': 3,
#  '번': 3,
#  '결심': 3,
#  '구속': 3,
#  '여의도': 3,
#  '회관': 3,
#  '해양수산부': 3,
#  '한나라당': 3,
#  '우리당': 3,
#  '합류': 3,
#  '독수리': 3,
#  '헌법': 3,
#  '군포': 3,
#  '수산': 3,
#  '남성': 3,
#  '첫발': 3,
#  '폭로': 3,
#  '차출': 3,
#  '국토부': 3,
#  '김상조': 3,
#  '분양': 3,
#  '전매': 3,
#  '표결': 3,
#  '불참': 3,
#  '자치': 3,
#  '체육관': 3,
#  '광부': 3,
#  '충북': 3,
#  '청주시': 3,
#  '최순실': 3,
#  '이익': 3,
#  '저': 3,
#  '은': 3,
#  '대신': 3,
#  '거부': 3,
#  '보건복지부': 3,
#  '토론회': 3,
#  '성공': 3,
#  '협상': 3,
#  '전남대': 3,
#  '일어난다': 3,
#  '기성': 3,
#  '채널': 3,
#  '영상': 3,
#  '진입': 3,
#  '격의': 3,
#  '목': 3,
#  '집단': 3,
#  '좌파': 3,
#  '민영화': 3,
#  '박석': 3,
#  '돈키호테': 3,
#  '수가': 3,
#  '협의': 3,
#  '너무': 3,
#  '영리': 3,
#  '자회사': 3,
#  '이해관계': 3,
#  '이미지': 3,
#  '김한길': 3,
#  '발전': 3,
#  '광장': 3,
#  '지지자': 3,
#  '영혼': 3,
#  '허물': 3,
#  '종로구': 3,
#  '만들기': 3,
#  '조언': 3,
#  '라디오': 3,
#  '여론조사': 3,
#  '고문': 3,
#  '일대일': 3,
#  '빌딩': 3,
#  '성명': 3,
#  '철수': 3,
#  '선택': 3,
#  '구태': 3,
#  '공학': 3,
#  '대결': 3,
#  '여망': 3,
#  '강원': 3,
#  '택': 3,
#  '대안': 3,
#  '제보': 3,
#  '조작': 3,
#  '동교동계': 3,
#  '기업인': 3,
#  '창조': 3,
#  '창조경제': 3,
#  '협력': 3,
#  '결집': 3,
#  '초기': 2,
#  '주말': 2,
#  '백악관': 2,
#  '달': 2,
#  '워싱턴': 2,
#  '중국': 2,
#  '일본': 2,
#  '대사': 2,
#  '청와대로': 2,
#  '불똥': 2,
#  '해당': 2,
#  '미리': 2,
#  '개인': 2,
#  '파장': 2,
#  '해촉': 2,
#  '위촉': 2,
#  '차례': 2,
#  '일찌': 2,
#  '감치': 2,
#  '균': 2,
#  '열': 2,
#  '김정은': 2,
#  '포기': 2,
#  '전제': 2,
#  '연쇄': 2,
#  '조명': 2,
#  '세운': 2,
#  '양국': 2,
#  '강경화': 2,
#  '정점': 2,
#  '외교학': 2,
#  '강행': 2,
#  '판단': 2,
#  '후임': 2,
#  '봉합': 2,
#  '상태': 2,
#  '중진': 2,
#  '불': 2,
#  '초점': 2,
#  '대체로': 2,
#  '뉴딜': 2,
#  '눈': 2,
#  '도심': 2,
#  '아파트': 2,
#  '특별법': 2,
#  '살': 2,
#  '마을': 2,
#  '도시': 2,
#  '건설': 2,
#  '업체': 2,
#  '매년': 2,
#  '기금': 2,
#  '공사': 2,
#  '공적': 2,
#  '활성화': 2,
#  '진행': 2,
#  '중이': 2,
#  '마련': 2,
#  '맞춤': 2,
#  '민간': 2}

# %%
b= set(test.keys())

# %%
b
# Out:
# {'오전',
#  '검찰총장',
#  '관료',
#  '시대',
#  '판사',
#  '주자',
#  '금융',
#  '시한',
#  '대신',
#  '행정자치부',
#  '안철수',
#  '긴장',
#  '세력',
#  '부총리',
#  '출신',
#  '전문가',
#  '본부',
#  '새누리당',
#  '간',
#  '목표',
#  '체육',
#  '시행',
#  '협치',
#  '설',
#  '경우',
#  '적발',
#  '입각',
#  '채널',
#  '군',
#  '속',
#  '방안',
#  '재원',
#  '공개',
#  '업무',
#  '학교',
#  '더',
#  '뿐',
#  '김정숙',
#  '탄핵',
#  '사학',
#  '이상',
#  '수도',
#  '국토교통부',
#  '도입',
#  '보궐선거',
#  '지지율',
#  '약속',
#  '과거',
#  '홍',
#  '가의',
#  '연합',
#  '내부',
#  '만들기',
#  '곳',
#  '특별',
#  '경제',
#  '기소권',
#  '홍종학',
#  '볼',
#  '영부인',
#  '씨',
#  '고문',
#  '시인',
#  '조국',
#  '동교동계',
#  '석비',
#  '민생',
#  '재개발',
#  '환경',
#  '라디오',
#  '조금',
#  '수장',
#  '핵심',
#  '구속',
#  '무기',
#  '가맹',
#  '최대',
#  '서관',
#  '미리',
#  '예술',
#  '오후',
#  '국본',
#  '달성',
#  '학자',
#  '우리당',
#  '발언',
#  '진영',
#  '법무',
#  '체계',
#  '인준',
#  '규모',
#  '에서',
#  '수산',
#  '꿈',
#  '경영',
#  '순',
#  '남성',
#  '모임',
#  '치',
#  '식',
#  '활성화',
#  '진',
#  '본부장',
#  '회사',
#  '불참',
#  '업체',
#  '추진',
#  '일어난다',
#  '다시',
#  '국가',
#  '신',
#  '국토',
#  '법인세',
#  '위원장',
#  '준비',
#  '기이',
#  '사퇴',
#  '타',
#  '탈당',
#  '임대',
#  '거부',
#  '명예',
#  '압박',
#  '분',
#  '축소',
#  '질문',
#  '박성원',
#  '부자',
#  '해양수산부',
#  '타파',
#  '분위기',
#  '하나',
#  '명의',
#  '거론',
#  '동아일보',
#  '주장',
#  '자신',
#  '일이',
#  '더욱',
#  '방침',
#  '활동',
#  '기간',
#  '기금',
#  '협상',
#  '중국',
#  '블랙리스트',
#  '합당',
#  '여론조사',
#  '노',
#  '주거',
#  '표명',
#  '목',
#  '캠프',
#  '가치',
#  '급',
#  '돈키호테',
#  '조직',
#  '우선',
#  '강',
#  '강연',
#  '눈앞',
#  '열흘',
#  '당장',
#  '믹스',
#  '평가',
#  '고액',
#  '위원',
#  '벽',
#  '격의',
#  '건강',
#  '처음',
#  '세무조사',
#  '철수',
#  '공약',
#  '한상준',
#  '교육',
#  '여당',
#  '세제',
#  '강행',
#  '이번',
#  '전자',
#  '해병대',
#  '위반',
#  '좌파',
#  '산행',
#  '차출',
#  '제대로',
#  '성장',
#  '소병철',
#  '표결',
#  '판단',
#  '첫발',
#  '바보',
#  '후보자',
#  '부담',
#  '며',
#  '의장',
#  '수가',
#  '배',
#  '방법',
#  '공식',
#  '계획',
#  '당초',
#  '채',
#  '경력',
#  '강화',
#  '권리',
#  '전체',
#  '만',
#  '뉴딜',
#  '의지',
#  '인선',
#  '비',
#  '김상곤',
#  '단장',
#  '무',
#  '재정',
#  '길',
#  '집단',
#  '증세',
#  '또',
#  '법안',
#  '김순덕',
#  '공학',
#  '상태',
#  '초기',
#  '관계자',
#  '조작',
#  '단일',
#  '다른',
#  '원',
#  '개편',
#  '정국',
#  '실제',
#  '횡설수설',
#  '성공',
#  '차례',
#  '소득세',
#  '경쟁',
#  '인천',
#  '민영화',
#  '주택',
#  '상권',
#  '자리',
#  '이사',
#  '검토',
#  '성',
#  '세율',
#  '결정',
#  '박석',
#  '기득권',
#  '선언',
#  '북한',
#  '환',
#  '그간',
#  '홍은동',
#  '총장',
#  '경북',
#  '대결',
#  '추천',
#  '현',
#  '사회',
#  '이자',
#  '매년',
#  '배치',
#  '건물',
#  '차별',
#  '거듭',
#  '바람',
#  '관',
#  '간부',
#  '연구원',
#  '면제',
#  '관계',
#  '학부',
#  '청와대로',
#  '준',
#  '신당',
#  '미국',
#  '논란',
#  '책임',
#  '인물',
#  '민간',
#  '못',
#  '로서',
#  '공석',
#  '구현',
#  '지역',
#  '이유',
#  '당권',
#  '모두',
#  '문화',
#  '총학생회',
#  '이기',
#  '기',
#  '양성평등',
#  '안정',
#  '당선',
#  '보건복지부',
#  '공천',
#  '듯',
#  '회',
#  '교과서',
#  '물망',
#  '전술핵',
#  '발전',
#  '결과',
#  '시도',
#  '건설',
#  '뉴시스',
#  '이전',
#  '경선',
#  '공공',
#  '출마',
#  '끝',
#  '내',
#  '경험',
#  '측은',
#  '청와대',
#  '광주',
#  '간섭',
#  '권력',
#  '일부',
#  '국정교과서',
#  '지능',
#  '신임',
#  '일',
#  '국방',
#  '금지',
#  '청구',
#  '대법원',
#  '난맥',
#  '복안',
#  '브레인',
#  '대전',
#  '제보',
#  '갈등',
#  '두',
#  '유권자',
#  '주기',
#  '해양',
#  '부채',
#  '비상',
#  '잡음',
#  '칼럼',
#  '공',
#  '창조경제',
#  '지난해',
#  '연',
#  '사태',
#  '필요',
#  '따윈',
#  '후보',
#  '격진',
#  '세운',
#  '쇄신',
#  '수사',
#  '상징',
#  '박정희',
#  '말',
#  '때문',
#  '직접',
#  '여사',
#  '알',
#  '임명',
#  '저',
#  '가계',
#  '내용',
#  '공급',
#  '대우조선',
#  '국가안보실',
#  '유력',
#  '폭로',
#  '경기도',
#  '장비',
#  '기념우표',
#  '혁신',
#  '비판',
#  '과',
#  '표정',
#  '법정',
#  '행사',
#  '아파트',
#  '대검찰청',
#  '양',
#  '한나라당',
#  '기사',
#  '일단',
#  '마련',
#  '자치',
#  '절반',
#  '참모',
#  '이익',
#  '직후',
#  '구상',
#  '정상회담',
#  '반발',
#  '칼',
#  '조윤제',
#  '광장',
#  '점',
#  '대표',
#  '선거',
#  '편찬',
#  '포석',
#  '논의',
#  '초',
#  '국회',
#  '한반도',
#  '새',
#  '당내',
#  '이후',
#  '포스코',
#  '반대',
#  '정점',
#  '전제',
#  '교수',
#  '서울대',
#  '한국',
#  '앞',
#  '과정',
#  '정도',
#  '대북',
#  '실장',
#  '타이밍',
#  '도',
#  '힘',
#  '정비',
#  '교육부',
#  '기수',
#  '자회사',
#  '빌딩',
#  '임',
#  '일정',
#  '물론',
#  '토론회',
#  '연세대',
#  '이',
#  '분석',
#  '통화',
#  '예산',
#  '전망',
#  '제재',
#  '와',
#  '탈세',
#  '자택',
#  '트럼프',
#  '경영학',
#  '법인',
#  '현행',
#  '보',
#  '최순실',
#  '보험',
#  '조언',
#  '기자',
#  '친구',
#  '진행',
#  '청문회',
#  '이해관계',
#  '균',
#  '취임',
#  '측',
#  '중이',
#  '명분',
#  '기존',
#  '대한',
#  '당시',
#  '김영춘',
#  '데',
#  '료',
#  '센터',
#  '주민',
#  '각각',
#  '목소리',
#  '부산',
#  '관저',
#  '구조',
#  '박근혜',
#  '제',
#  '도움',
#  '보기',
#  '창조',
#  '개',
#  '성명',
#  '투쟁',
#  '전의총',
#  '김경수',
#  '회의',
#  '달라',
#  '최근',
#  '조현',
#  '년',
#  '김한길',
#  '사업',
#  '조정',
#  '노무현',
#  '전',
#  '게',
#  '대형',
#  '직전',
#  '체육관',
#  '윤',
#  '부실',
#  '차기',
#  '우리',
#  '대사',
#  '재',
#  '정당',
#  '무소속',
#  '장기',
#  '오랫동안',
#  '안보',
#  '이하',
#  '청주시',
#  '무상급식',
#  '검사',
#  '해촉',
#  '겸',
#  '연대',
#  '수',
#  '수사권',
#  '율',
#  '범',
#  '동시',
#  '눈',
#  '기본',
#  '영향력',
#  '차관',
#  '당',
#  '공수',
#  '내각',
#  '사드',
#  '전통',
#  '사법연수원',
#  '대한민국',
#  '반도',
#  '얘기',
#  '먼저',
#  '오른쪽',
#  '국세청',
#  '외부',
#  '하자',
#  '대학원',
#  '대해',
#  '책',
#  '서민',
#  '모든',
#  '국회의원',
#  '전면',
#  '변화',
#  '정',
#  '최고',
#  '안배',
#  '생각',
#  '산업',
#  '발행',
#  '안팎',
#  '폐지',
#  '과제',
#  '운동',
#  '만큼',
#  '것',
#  '주거지',
#  '까지',
#  '한마디',
#  '이미지',
#  '포기',
#  '특별법',
#  '백악관',
#  '역사',
#  '휴대전화',
#  '모습',
#  '돈',
#  '스포트라이트',
#  '도시',
#  '라며',
#  '선택',
#  '한편',
#  '위원회',
#  '청년',
#  '해군',
#  '합',
#  '행보',
#  '마을',
#  '국토부',
#  '대구',
#  '친',
#  '전날',
#  '검찰',
#  '임종석',
#  '부처',
#  '협의',
#  '서울',
#  '구체',
#  '빚',
#  '중소',
#  '중진',
#  '중앙',
#  '의원',
#  '확보',
#  '풀이',
#  '성과',
#  '현역',
#  '무대',
#  '일대일',
#  '스스로',
#  '민주당',
#  '줄',
#  '미사일방어',
#  '그',
#  '번',
#  '위기',
#  '소통',
#  '은',
#  '이낙연',
#  '수준',
#  '외교부',
#  '상임',
#  '전남대',
#  '여망',
#  '차장',
#  '등',
#  '라인',
#  '박지원',
#  '대통령',
#  '불똥',
#  '대법관',
#  '최',
#  '지지자',
#  '파업',
#  '한국사',
#  '국장',
#  '입',
#  '대변인',
#  '통합신당',
#  '카드',
#  '유통업체',
#  '교육감',
#  '시간',
#  '독수리',
#  '방어',
#  '조',
#  '대체로',
#  '중심',
#  '순위',
#  '개발',
#  '경기',
#  '전교조',
#  '각종',
#  '공동',
#  '변호사',
#  '초과',
#  '참모총장',
#  '사람',
#  '임기',
#  '실현',
#  '안',
#  '통해',
#  '이용섭',
#  '살',
#  '동물원',
#  '역대',
#  '의미',
#  '합류',
#  '특보',
#  '광부',
#  '추가',
#  '고',
#  '기업인',
#  '주변',
#  '지금',
#  '반',
#  '대통',
#  '서명',
#  '바',
#  '봉합',
#  '주도',
#  '정치인',
#  '박사',
#  '시절',
#  '종로구',
#  '군포',
#  '화제',
#  '너무',
#  '총선',
#  '늘',
#  '사의',
#  '주말',
#  '김수남',
#  '발탁',
#  '제한',
#  '개월',
#  '주의',
#  '뒤',
#  '문',
#  '위해',
#  '지원',
#  '자산',
#  '옥',
#  '기준',
#  '대통령비서실장',
#  '비서실',
#  '역할',
#  '구도',
#  '인',
#  '대책',
#  '정부',
#  '온',
#  '임대주택',
#  '초점',
#  '장관',
#  '연구',
#  '사과',
#  '등산',
#  '위촉',
#  '건',
#  '전매',
#  '헌법',
#  '문정인',
#  '민정',
#  '눈물',
#  '법',
#  '대검',
#  '김현미',
#  '간사',
#  '단계',
#  '현재',
#  '강경화',
#  '효과',
#  '문체부',
#  '교통',
#  '부분',
#  '공감',
#  '결집',
#  '관리',
#  '여성',
#  '반드시',
#  '선수',
#  '미래',
#  '총량',
#  '고고',
#  '적지',
#  '회장',
#  '파괴',
#  '시장',
#  '여의도',
#  '열',
#  '체제',
#  '고려대',
#  '김상조',
#  '교체',
#  '기자회견',
#  '숙명',
#  '언급',
#  '원장',
#  '강원',
#  '층',
#  '대상',
#  '국민',
#  '이야기',
#  '비수',
#  '공사',
#  '영리',
#  '비율',
#  '대안',
#  '택',
#  '도전',
#  '권한',
#  '제도',
#  '명',
#  '기초',
#  '박원순',
#  '김정은',
#  '원대',
#  '맞춤',
#  '뉴스',
#  '양국',
#  '국정',
#  '월',
#  '정치권',
#  '지난',
#  '가능성',
#  '개인',
#  '해결',
#  '소득',
#  '중',
#  '친문',
#  '그룹',
#  '통일부',
#  '대출',
#  '돌파',
#  '방향',
#  '우려',
#  '분야',
#  '회생',
#  '참여',
#  '벤처기업',
#  '국민의당',
#  '인터넷',
#  '승희',
#  '달',
#  '절대',
#  '로부터',
#  '비서',
#  '재직',
#  '전격',
#  '도심',
#  '분수',
#  '충북',
#  '시',
#  '정책',
#  '후',
#  '보고',
#  '처',
#  '의료',
#  '적',
#  '날',
#  '김',
#  '통한',
#  '가계부채',
#  '민주',
#  '하되',
#  '지명',
#  '위',
#  '검증',
#  '호남',
#  '막',
#  '사실',
#  '베스트',
#  '첫',
#  '일본',
#  '몇',
#  '보호',
#  '선',
#  '일찌',
#  '발표',
#  '저울',
#  '차',
#  '먹통',
#  '조광',
#  '석',
#  '경찰',
#  '성향',
#  '선대',
#  '노동조합',
#  '오히려',
#  '시험대',
#  '합의',
#  '김부겸',
#  '금',
#  '독자',
#  '사설',
#  '접시꽃',
#  '정무',
#  '진입',
#  '때',
#  '상황',
#  '라면',
#  '속도',
#  '규제',
#  '야권',
#  '신설',
#  '지지',
#  '부동산',
#  '비리',
#  '국방부',
#  '대기업',
#  '감안',
#  '법무부',
#  '과표',
#  '의협',
#  '총',
#  '억',
#  '일각',
#  '지방',
#  '얼마나',
#  '전문',
#  '논설',
#  '도시재생',
#  '해당',
#  '허물',
#  '영입',
#  '회동',
#  '론',
#  '뜻',
#  '기업',
#  '분열',
#  '장',
#  '폭탄',
#  '인상',
#  '결심',
#  '기성',
#  '연쇄',
#  '관련',
#  '부인',
#  '여',
#  '과연',
#  '감',
#  '북핵',
#  '제기',
#  '영상',
#  '실무',
#  '워싱턴',
#  '법원행정처',
#  '검',
#  '호소',
#  '바로',
#  '가족',
#  '서울시장',
#  '인사',
#  '본인',
#  '구태',
#  '박',
#  '현실',
#  '왼쪽',
#  '걸',
#  '개입',
#  '반영',
#  '노환규',
#  '단체',
#  '후임',
#  '문제',
#  '진보',
#  '평',
#  '이삿짐',
#  '조사',
#  '물',
#  '수석',
#  '지방선거',
#  '골목',
#  '촉구',
#  '도종환',
#  '반응',
#  '조명',
#  '대선',
#  '고위',
#  '거',
#  '질',
#  '파장',
#  '외교학',
#  '의견',
#  '입장',
#  '사전',
#  '그동안',
#  '로',
#  '문재인',
#  '노후',
#  '통합',
#  '개혁',
#  '국사',
#  '의혹',
#  '및',
#  '창',
#  '회관',
#  '방법론',
#  '취지',
#  '송',
#  '진정',
#  '크게',
#  '다만',
#  '손',
#  '정권',
#  '자기',
#  '금리',
#  '가장',
#  '전국',
#  '외교',
#  '미사일',
#  '의사',
#  '총리',
#  '현직',
#  '영혼',
#  '불',
#  '셈',
#  '지난달',
#  '관측',
#  '한미',
#  '공적',
#  '당신',
#  '새정치',
#  '정치',
#  '를',
#  '세금',
#  '집',
#  '확대',
#  '송영',
#  '사진',
#  '운',
#  '사건',
#  '대부분',
#  '분양',
#  '운영',
#  '부장',
#  '혹시',
#  '감치',
#  '김진표',
#  '의',
#  '봉욱',
#  '협력',
#  '일자리'}

# %%
set_nw = list(nw_s & b)
set_pw = list(pw_s & b)

# %%
set_nw
# Out:
# ['의혹',
#  '간섭',
#  '부실',
#  '오랫동안',
#  '정부',
#  '이익',
#  '일',
#  '폭탄',
#  '반발',
#  '칼',
#  '금지',
#  '도전',
#  '크게',
#  '책임',
#  '감',
#  '발표',
#  '가장',
#  '상태',
#  '갈등',
#  '빚',
#  '초과',
#  '부채',
#  '인사',
#  '반대',
#  '경쟁',
#  '문제',
#  '우려',
#  '위기',
#  '투쟁',
#  '파괴',
#  '홍',
#  '열',
#  '거부',
#  '위반',
#  '압박',
#  '포기',
#  '고문',
#  '비판',
#  '적',
#  '제한',
#  '지방',
#  '바보',
#  '국민',
#  '차별',
#  '부담']

# %%
set_pw
# Out:
# ['양',
#  '구속',
#  '대사',
#  '자신',
#  '이익',
#  '진행',
#  '인상',
#  '권리',
#  '베스트',
#  '장관',
#  '관련',
#  '보호',
#  '연대',
#  '기초',
#  '가치',
#  '초과',
#  '원',
#  '성공',
#  '건강',
#  '안정',
#  '이상',
#  '구조',
#  '금',
#  '기이',
#  '약속',
#  '정치',
#  '최고',
#  '지지',
#  '운',
#  '명예',
#  '조명',
#  '추천',
#  '지지자',
#  '혁신',
#  '지원',
#  '개혁']

# %%
test[set_nw[0]]
# Out:
# 8

# %%
for nw in set_nw:
    score -= test[nw]

for pw in set_pw:
    score +=test[pw]

# %%
score
# Out:
# 48

# %%
#from konlpy.tag import Twitter

# %%
def cheak_socre (file_name):
    score = 0
    test = read_pfile(file_name)

    b= set(test.keys())

    set_nw = list(nw_s & b)
    set_pw = list(pw_s & b)

    for nw in set_nw:
        score -= test[nw]

    for pw in set_pw:
        score +=test[pw]
    
    return score

# %%
cheak_socre("test.txt")
# Out:
# 48
